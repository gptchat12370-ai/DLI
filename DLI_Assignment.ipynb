# %% [markdown]
# <a href="https://colab.research.google.com/github/gptchat12370-ai/DLI/blob/main/DLI_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("lleratodev/ai-powered-phishing-email-detection-system", cache_dir="/content/DLI")
# Out:
# Generating train split:   0%|          | 0/49860 [00:00<?, ? examples/s]

# %%
import pandas as pd
data_train = pd.read_csv("/content/1/phishing_email.csv")

# %%
# Check data
data_train.head()
# Out:
#                                        text_combined  label
# 0  hpl nom may 25 2001 see attached file hplno 52...      0
# 1  nom actual vols 24 th forwarded sabrae zajac h...      0
# 2  enron actuals march 30 april 1 201 estimated a...      0
# 3  hpl nom may 30 2001 see attached file hplno 53...      0
# 4  hpl nom june 1 2001 see attached file hplno 60...      0

# %%
print(f"The dataset has {data_train.shape[0]} rows.")
# Out:
# The dataset has 82486 rows.

# %% [markdown]
# **Important:** Before running the following cells, make sure you have Git configured in your environment. If you haven't already, you might need to set up your Git username and email using the following commands in a code cell:

# %%
# Add all changes to the staging area
# !git add .

# Commit the changes
# !git commit -m "Add/update notebook"

# Push the changes to the remote repository (e.g., 'origin' and 'main' branch)
# You might need to replace 'origin' and 'main' with your remote name and branch name
# !git push origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
